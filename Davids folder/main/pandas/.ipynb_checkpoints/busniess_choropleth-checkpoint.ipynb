# %%
import io
import plotly.graph_objs as go 
from plotly.offline import plot

# %%
import pandas as pd

# %%
df = pd.read_csv('merge_state.csv')

# %%
df.head()
# Out:
#   STATE DESCRIPTION NAICS CODE                NAICS DESCRIPTION  \
# 0           Alabama         72  Accommodation and food services
# 1           Alabama         72  Accommodation and food services
# 2            Alaska         72  Accommodation and food services
# 3            Alaska         72  Accommodation and food services
# 4           Arizona         72  Accommodation and food services
#
#   ENTERPRISE EMPLOYMENT SIZE  EMPLOYMENT  ANNUAL PAYROLL ($1,000)  YEAR  \
# 0                  8:   <500       87643                  1007346  2008
# 1                  9:   500+       71916                   891633  2008
# 2                  8:   <500       18389                   377677  2008
# 3                  9:   500+        6504                   195212  2008
# 4                  8:   <500      140409                  1883873  2008
#
#      State Code
# 0  Alabama   AL
# 1  Alabama   AL
# 2   Alaska   AK
# 3   Alaska   AK
# 4  Arizona   AZ

# %%
less_than = df[df["ENTERPRISE EMPLOYMENT SIZE"] == "8:   <500"]
less_than.head()
# Out:
#   STATE DESCRIPTION NAICS CODE                NAICS DESCRIPTION  \
# 0           Alabama         72  Accommodation and food services
# 2            Alaska         72  Accommodation and food services
# 4           Arizona         72  Accommodation and food services
# 6          Arkansas         72  Accommodation and food services
# 8        California         72  Accommodation and food services
#
#   ENTERPRISE EMPLOYMENT SIZE  EMPLOYMENT  ANNUAL PAYROLL ($1,000)  YEAR  \
# 0                  8:   <500       87643                  1007346  2008
# 2                  8:   <500       18389                   377677  2008
# 4                  8:   <500      140409                  1883873  2008
# 6                  8:   <500       63975                   707797  2008
# 8                  8:   <500      847353                 13581804  2008
#
#         State Code
# 0     Alabama   AL
# 2      Alaska   AK
# 4     Arizona   AZ
# 6    Arkansas   AR
# 8  California   CA

# %%
more_than = df[df["ENTERPRISE EMPLOYMENT SIZE"] == "9:   500+"]
more_than.head()
# Out:
#   STATE DESCRIPTION NAICS CODE                NAICS DESCRIPTION  \
# 1           Alabama         72  Accommodation and food services
# 3            Alaska         72  Accommodation and food services
# 5           Arizona         72  Accommodation and food services
# 7          Arkansas         72  Accommodation and food services
# 9        California         72  Accommodation and food services
#
#   ENTERPRISE EMPLOYMENT SIZE  EMPLOYMENT  ANNUAL PAYROLL ($1,000)  YEAR  \
# 1                  9:   500+       71916                   891633  2008
# 3                  9:   500+        6504                   195212  2008
# 5                  9:   500+      119112                  2075716  2008
# 7                  9:   500+       29583                   367188  2008
# 9                  9:   500+      562065                 10682982  2008
#
#         State Code
# 1     Alabama   AL
# 3      Alaska   AK
# 5     Arizona   AZ
# 7    Arkansas   AR
# 9  California   CA

# %%
# data = dict(
#         type = 'choropleth',
#         colorscale = 'Blues',
#      autocolorscale=False,
#         reversescale = False,
#         locations = df['Code'],
#         locationmode = "USA-states",
#         z = df['EMPLOYMENT'],
#         text = df['STATE DESCRIPTION'],
#         marker = dict(line = dict(color = 'rgb(255,255,255)',width = 1)),
#         colorbar = {'title' : 'Number of Employment'},
#       )

# %%
# layout = dict(geo = dict(scope='usa', showlakes= False))

# %%
# choromap = go.Figure(data=[data], layout=layout)
# plot(choromap)
