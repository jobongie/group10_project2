# %%
import io
import plotly.graph_objs as go 
from plotly.offline import plot

# %%
import pandas as pd

# %%
df = pd.read_csv('../../../static/data/table_df.csv')

# %%
df.head()
# Out:
#    YEAR STATE_DESCRIPTION STATE_CODE NAICS_CODE  \
# 0  2008           Alabama         AL         11
# 1  2008           Alabama         AL         11
# 2  2008           Alabama         AL         11
# 3  2008           Alabama         AL         11
# 4  2008           Alabama         AL         11
#
#                                      INDUSTRY ENTERPRISE_EMPLOYMENT_SIZE  \
# 0  Agriculture, Forestry, Fishing and Hunting                        0-4
# 1  Agriculture, Forestry, Fishing and Hunting                        5-9
# 2  Agriculture, Forestry, Fishing and Hunting                      10-19
# 3  Agriculture, Forestry, Fishing and Hunting                      20-99
# 4  Agriculture, Forestry, Fishing and Hunting                    100-499
#
#   BUSINESS_CLASSIFICATION SECTOR  NUMBER_OF_FIRMS  NUMBER_OF_ESTABLISHMENTS  \
# 0                     NaN  N/A11              433                       433
# 1                     NaN  N/A11              259                       259
# 2                     NaN  N/A11              112                       112
# 3                     NaN  N/A11               49                        52
# 4                     NaN  N/A11                5                         8
#
#    EMPLOYMENT  ANNUAL_PAYROLL  COLOR_GROUP
# 0         867        25451000          NaN
# 1        1708        48440000          NaN
# 2        1468        47620000          NaN
# 3        1518        51445000          NaN
# 4         516        16384000          NaN

# %%
more_than = df[df["ENTERPRISE_EMPLOYMENT_SIZE"] == "500+"]
more_than.head()
# Out:
#     YEAR STATE_DESCRIPTION STATE_CODE NAICS_CODE  \
# 5   2008           Alabama         AL         11
# 11  2008           Alabama         AL         21
# 22  2008           Alabama         AL         23
# 28  2008           Alabama         AL      31-33
# 34  2008           Alabama         AL         42
#
#                                          INDUSTRY ENTERPRISE_EMPLOYMENT_SIZE  \
# 5      Agriculture, Forestry, Fishing and Hunting                       500+
# 11  Mining, Quarrying, and Oil and Gas Extraction                       500+
# 22                                   Construction                       500+
# 28                                  Manufacturing                       500+
# 34                                Wholesale Trade                       500+
#
#    BUSINESS_CLASSIFICATION  SECTOR  NUMBER_OF_FIRMS  NUMBER_OF_ESTABLISHMENTS  \
# 5           Large Business     L11               12                        26
# 11          Large Business     L21               44                        92
# 22          Large Business     L23               83                       184
# 28          Large Business  L31-33              426                       861
# 34          Large Business     L42              394                      1059
#
#     EMPLOYMENT  ANNUAL_PAYROLL  COLOR_GROUP
# 5          351        19115000          2.0
# 11        4744       327408000          2.0
# 22       19199       942594000          2.0
# 28      183633      8213256000          2.0
# 34       30084      1494823000          2.0

# %%
# year = 2008

# %%
# df_segmented = less_than[(less_than['YEAR']== year )]

# %%
# for col in df_segmented.columns:
#     df_segmented[col] = df_segmented[col].astype(str)

# %%
# for col in df_segmented.columns:
#         df_segmented[col] = df_segmented[col].astype(str)

# %%
#     data_each_yr = dict(
#                         type='choropleth',
#                         locations = df_segmented['Code'],
#                         z=df_segmented['EMPLOYMENT'].astype(float),
#                         locationmode='USA-states')

#     data_slider.append(data_each_yr)

# %%
# data = dict(
#         type = 'choropleth',
#         locations = less_than['Code'].astype(str),
#         locationmode = "USA-states",
#         z = less_than['EMPLOYMENT'].astype(float),
#         marker = dict(line = dict(color = 'rgb(255,255,255)',width = 1))
#       )

# layout = dict(geo = dict(scope='usa', showlakes= False))

# %%
# steps = []
# for i in range(len(data_slider)):
#     step = dict(method='restyle',
#                 args=['visible', [False] * len(data_slider)],
#                 label='Year {}'.format(i + 2008))
#     step['args'][1][i] = True
#     steps.append(step)

# sliders = [dict(active=0, pad={"t": 1}, steps=steps)]

# %%
# layout = dict(geo=dict(scope='usa',
#                        projection={'type': 'albers usa'}),
#               sliders=sliders)

# %%
# # choromap = go.Figure(data=data_slider, layout=layout)
# choromap = go.Figure(data = [data],layout = layout)
# plot(choromap)
