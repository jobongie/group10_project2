# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd

import scipy.stats as st
import numpy as np
from citipy import citipy
import time
import json
from pprint import pprint
# Out:
# In C:\Users\zorta\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\zorta\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\zorta\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\zorta\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
small_business_path = "data/small_business_data.csv"
large_business_path = "data/large_business_data.csv"


# Read the mouse data and the study results
small_business = pd.read_csv(small_business_path)
large_business = pd.read_csv(large_business_path)

# %%
merge = pd.merge(small_business,large_business,  how='left', left_on=['YEAR','STATE DESCRIPTION','INDUSTRY'], right_on = ['YEAR','STATE DESCRIPTION','INDUSTRY'])
merge.head(10)
# Out:
#    YEAR STATE DESCRIPTION STATE _CODE_x NAICS_CODE_x  \
# 0  2012           Alabama            AL           11
# 1  2012           Alabama            AL           21
# 2  2012           Alabama            AL           22
# 3  2012           Alabama            AL           23
# 4  2012           Alabama            AL           42
# 5  2012           Alabama            AL           51
# 6  2012           Alabama            AL           52
# 7  2012           Alabama            AL           53
# 8  2012           Alabama            AL           54
# 9  2012           Alabama            AL           55
#
#                                            INDUSTRY  \
# 0        Agriculture, forestry, fishing and hunting
# 1     Mining, quarrying, and oil and gas extraction
# 2                                         Utilities
# 3                                      Construction
# 4                                   Wholesale trade
# 5                                       Information
# ...

# %%
merge.to_csv("data/new_business_data_chart.csv", index = False)
